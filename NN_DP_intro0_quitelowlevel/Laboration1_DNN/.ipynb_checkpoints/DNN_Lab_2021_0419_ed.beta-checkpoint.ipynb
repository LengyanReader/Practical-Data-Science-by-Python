# %% [markdown]
# # Deep Neural Networks Laboration
#
# Data used in this laboration are from the Kitsune Network Attack Dataset, https://archive.ics.uci.edu/ml/datasets/Kitsune+Network+Attack+Dataset . We will focus on the 'Mirai' part of the dataset. Your task is to make a DNN that can classify if each attack is benign or malicious. The dataset has 116 covariates, but to make it a bit more difficult we will remove the first 24 covariates.
#
# You need to answer all questions in this notebook.

# %% [markdown]
# # Part 1: Get the data
#
# Skip this part if you load stored numpy arrays (Mirai*.npy) (which is recommended)
#
# Use `wget` in the terminal of your cloud machine (in the same directory as where you have saved this notebook) to download the data, i.e.
#
# wget https://archive.ics.uci.edu/ml/machine-learning-databases/00516/mirai/Mirai_dataset.csv.gz
#
# wget https://archive.ics.uci.edu/ml/machine-learning-databases/00516/mirai/Mirai_labels.csv.gz
#
# Then unpack the files using `gunzip` in the terminal, i.e.
#
# gunzip Mirai_dataset.csv.gz
#
# gunzip Mirai_labels.csv.gz

# %% [markdown]
# # Part 2: Get a graphics card
#
# Skip this part if you run on the CPU
#
# Lets make sure that our script can see the graphics card that will be used. The graphics cards will perform all the time consuming calculations in every training iteration.

# %%
import os
import warnings

# Ignore FutureWarning from numpy
warnings.simplefilter(action='ignore', category=FutureWarning)

import keras.backend as K
import tensorflow as tf



os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
 
# The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="0";

# Enable the XLA

os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'

# Allow growth of GPU memory, otherwise it will always look like all the memory is being used
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# # Part 3: Hardware
#
# Skip questions 1, 2, 3, 5, 6 if you use your own computer.
#
# In deep learning, the computer hardware is very important. You should always know what kind of hardware you are working on.
#
# Question 1: What graphics card is available in the cloud machine? Run 'nvidia-smi' in the terminal.
#
# Question 2: Google the name of the graphics card, how many CUDA cores does it have?
#
# Question 3: How much memory does the graphics card have?
#
# Question 4: What is stored in the GPU memory while training a DNN ?
#
#         Batch of data,parameters in network,gradients,etc.
#
# Question 5: What CPU is available in the cloud machine? How many cores does it have? Run 'lscpu' in the terminal.
#
# Question 6: How much CPU memory (RAM) is available in the cloud machine? Run 'free -g' in the terminal.

# %% [markdown]
# # Part 4: Load the data
#
# To make this step easier, directly load the data from saved numpy arrays (.npy) (recommended)
#
#
# Load the dataset from the csv files, it will take some time since it is almost 1.4 GB.
#
# We will use the function `genfromtxt` to load the data.
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.genfromtxt.html
#
# Load the data from csv files the first time, then save the data as numpy files for faster loading the next time.

# %%
from numpy import genfromtxt
import numpy as np

# Load data from numpy arrays
X = np.load('Mirai_data.npy')
Y = np.load('Mirai_labels.npy')



# Remove the first 24 covariates (columns)

X = np.delete(X,np.arange(0,24),axis=1)

print('The covariates have size {}.'.format(X.shape))
print('The labels have size {}.'.format(Y.shape))

# Print the number of examples of each class

k = 0

for i in Y:
    if i == 0:
        k = k+1
        pass
    pass
print("The number of examples of '0' calss {}.".format(k))
print("The number of examples of '1' calss {}.".format(len(Y)-k))
# Out:
# The covariates have size (764137, 92).
# The labels have size (764137,).
# The number of examples of '0' calss 121621.
# The number of examples of '1' calss 642516.

# %% [markdown]
# # Part 5: How good is a naive classifier?
#
# Question 7: Given the number of examples from each class, how high classification performance can a naive classifier obtain? The naive classifier will assume that all examples belong to one class. Note: you do not need to make a naive classifier, this is a theoretical question, just to understand how good performance we can obtain by guessing that all examples belong to one class.
#
#     The accuray of the classifier will be n_sample / n_total.

# %%
# It is common to have NaNs in the data, lets check for it. Hint: np.isnan()

# Print the number of NaNs (not a number) in the labels
k=0
for i in Y:
    if np.isnan(i)==True:
        k=k+1
        pass
    pass
print("Number of NaNs in the labels:",k)

# Print the number of NaNs in the covariates

k=0
for i in X:
    if np.isnan(i).any==True:
        k=k+1
        pass
    pass
print("Number of NaNs in the covariates:",k)
# Out:
# Number of NaNs in the labels: 0
# Number of NaNs in the covariates: 0

# %% [markdown]
# # Part 6: Preprocessing
#
# Lets do some simple preprocessing

# %%
# Convert covariates to floats

X=X.astype(np.float64)

# Convert labels to integers

Y=Y.astype(np.int)

# Remove mean of each covariate (column)

X=X-np.mean(X, axis=0,dtype=np.float64)

# Divide each covariate (column) by its standard deviation

X=X/np.std(X, axis=0,dtype=np.float64)

# Check that mean is 0 and standard deviation is 1 for all covariates, by printing mean and std

col_means = np.mean(X, axis=0)
col_std = np.std(X, axis=0)
print(col_means)
print(col_std)
# Out:
# [-2.61570467e-17  2.91009930e-16  1.75706916e-16  1.58299880e-16
#   5.57025141e-16  7.98938304e-17  1.11434784e-16  5.60409843e-16
#   2.42359497e-16 -5.41924166e-17 -2.47715508e-17 -7.32732057e-18
#   9.74496441e-18 -1.53985316e-17 -4.94538347e-16 -5.78746741e-17
#   6.27843509e-17 -7.65909569e-16  1.26926302e-17 -2.71520001e-18
#  -1.85972603e-17  4.00213042e-17  1.00343378e-15  1.43570850e-16
#  -7.64868123e-16  9.92163838e-18 -1.95643179e-17  1.50079891e-16
#  -3.67035530e-16 -7.58768221e-16 -1.69607014e-17 -7.58247498e-16
#  -6.26727673e-18 -2.04569864e-17 -1.04739770e-16 -8.08460101e-16
#   5.89012429e-16  1.20510247e-17 -3.86525459e-16 -2.28746302e-17
#  -7.43890413e-19  1.02656877e-16  5.60409843e-16 -3.04995069e-18
#   6.76010413e-18 -4.99299245e-16  1.00983124e-17  5.76701043e-17
#   3.98725261e-17  1.36875836e-17  4.71626522e-17 -3.61605130e-16
#  -1.32040548e-18 -2.93836713e-17 -1.78533699e-18  8.12328331e-17
# ...

# %% [markdown]
# # Part 7: Split the dataset
#
# Use the first 70% of the dataset for training, leave the other 30% for validation and test, call the variables
#
# Xtrain (70%)
#
# Xtemp  (30%)
#
# Ytrain (70%)
#
# Ytemp  (30%)
#
# We use a function from scikit learn.
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split

# Your code
Xtrain,Xtemp,Ytrain,Ytemp = train_test_split(X,Y, test_size=0.3, train_size=0.7, random_state=123, shuffle=True, stratify=None)


print('Xtrain has size {}.'.format(Xtrain.shape))
print('Ytrain has size {}.'.format(Ytrain.shape))

print('Xtemp has size {}.'.format(Xtemp.shape))
print('Ytemp has size {}.'.format(Ytemp.shape))

# Print the number of examples of each class, for the training data and the remaining 30%

print("Number of examples of class '0' for training data:",np.count_nonzero(Ytrain==0))
print("Number of examples of class '1' for training data:",np.count_nonzero(Ytrain==1))
print("Number of examples of class '0' for remaining data:",np.count_nonzero(Ytemp==0))
print("Number of examples of class '1' for remaining data:",np.count_nonzero(Ytemp==1))
# Out:
# Xtrain has size (534895, 92).
# Ytrain has size (534895,).
# Xtemp has size (229242, 92).
# Ytemp has size (229242,).
# Number of examples of class '0' for training data: 85249
# Number of examples of class '1' for training data: 449646
# Number of examples of class '0' for remaining data: 36372
# Number of examples of class '1' for remaining data: 192870

# %% [markdown]
# #  Part 8: Split non-training data data into validation and test
# Now split your non-training data (Xtemp, Ytemp) into 50% validation (Xval, Yval) and 50% testing (Xtest, Ytest), we use a function from scikit learn.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# Do all variables (Xtrain,Ytrain), (Xval,Yval), (Xtest,Ytest) have the shape that you expect?

# %%
from sklearn.model_selection import train_test_split

Xval,Xtest, Yval,Ytest = train_test_split(Xtemp,Ytemp, test_size=0.5, train_size=0.5, random_state=123, shuffle=True, stratify=None)


print('The validation and test data have size {}, {}, {} and {}'.format(Xval.shape, Xtest.shape, Yval.shape, Ytest.shape))
# Out:
# The validation and test data have size (114621, 92), (114621, 92), (114621,) and (114621,)

# %% [markdown]
# # Part 9: DNN classification
#
# Finish this code to create a first version of the classifier using a DNN. Start with a simple network with 2 dense layers (with 20 nodes each), using sigmoid activation functions. The final dense layer should have a single node and a sigmoid activation function. We start with the SGD optimizer.
#
# For different parts of this notebook you need to go back here, add more things, and re-run this cell to re-define the build function.
#
# Relevant functions are
#
# `model.add()`, adds a layer to the network
#
# `Dense()`, a dense network layer
#
# `model.compile()`, compile the model, add " metrics=['accuracy'] " to print the classification accuracy during the training
#
# See https://keras.io/layers/core/ for information on how the `Dense()` function works
#
# Import a relevant cost / loss function for binary classification from keras.losses (https://keras.io/losses/)
#
# See the following links for how to compile, train and evaluate the model
#
# https://keras.io/api/models/model_training_apis/#compile-method
#
# https://keras.io/api/models/model_training_apis/#fit-method
#
# https://keras.io/api/models/model_training_apis/#evaluate-method

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense
from keras.optimizers import SGD
#from keras.losses import ?
from keras.optimizers import Adam
from keras.layers import BatchNormalization
from keras.layers import Dropout

# Set seed from random number generator, for better comparisons
from numpy.random import seed
seed(123)

def build_DNN(input_shape, n_layers, n_nodes, act_fun='sigmoid', optimizer='sgd', learning_rate=0.01, 
              use_bn=False, use_dropout=False, use_custom_dropout=False):
    
    # Setup optimizer, depending on input parameter string
    if optimizer=='adam':
        opt = Adam(learning_rate)
        pass
    else:
        opt = SGD(learning_rate)
        
    # Setup a sequential model
    model = Sequential()
    
    # Add layers to the model, using the input parameters of the build_DNN function
    model.add(Input(shape=(input_shape,)))
    # Add first layer, requires input shape
    if use_bn==True:
        model.add(BatchNormalization())
        pass
    model.add(Dense(n_nodes,activation=act_fun))
    if use_dropout== True:
        model.add(Dropout(rate=0.5))
        pass
    if use_custom_dropout==True:
        model.add(myDropout(rate=0.5))
        pass
    # Add remaining layers, do not require input shape
    for i in range(n_layers-1):
        if use_bn==True:
            model.add(BatchNormalization())
            pass
        model.add(Dense(n_nodes,activation=act_fun))
        if use_dropout==True:
            model.add(Dropout(rate=0.5))
            pass
        if use_custom_dropout==True:
            model.add(myDropout(rate=0.5))
            pass
        pass
           
    # Final layer
    model.add(Dense(1,activation='sigmoid'))
 
    # Compile model
    model.compile(optimizer=opt,loss="binary_crossentropy",metrics=['accuracy'])
    
    return model

# %%
# Lets define a help function for plotting the training results

import matplotlib.pyplot as plt
def plot_results(history):
    
    val_loss = history.history['val_loss']
    acc = history.history['accuracy']
    loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    
    plt.figure(figsize=(10,4))
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(loss)
    plt.plot(val_loss)
    plt.legend(['Training','Validation'])

    plt.figure(figsize=(10,4))
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(acc)
    plt.plot(val_acc)
    plt.legend(['Training','Validation'])

    plt.show()

# %% [markdown]
# # Part 10: Train the DNN
#
# Time to train the DNN, we start simple with 2 layers with 20 nodes each, learning rate 0.1.
#
# Relevant functions
#
# `build_DNN`, the function we defined in Part 9, call it with the parameters you want to use
#
# `model.fit()`, train the model with some training data
#
# `model.evaluate()`, apply the trained model to some test data
#
# See the following links for how to train and evaluate the model
#
# https://keras.io/api/models/model_training_apis/#fit-method
#
# https://keras.io/api/models/model_training_apis/#evaluate-method

# %% [markdown]
# ### 2 layers, 20 nodes

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20

input_shape = X.shape[1]

# Build the model
model1 = build_DNN(input_shape, n_layers=2, n_nodes=20, act_fun='sigmoid', optimizer='sgd', learning_rate=0.1)

# Train the model, provide training data and validation data
history1 = model1.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval))
# Out:
# Epoch 1/20
# 54/54 [==============================] - 2s 15ms/step - loss: 0.5222 - accuracy: 0.7411 - val_loss: 0.3747 - val_accuracy: 0.8416
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3635 - accuracy: 0.8405 - val_loss: 0.3206 - val_accuracy: 0.8416
# Epoch 3/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3086 - accuracy: 0.8403 - val_loss: 0.2677 - val_accuracy: 0.8416
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2594 - accuracy: 0.8436 - val_loss: 0.2316 - val_accuracy: 0.8588
# Epoch 5/20
# 54/54 [==============================] - 0s 8ms/step - loss: 0.2276 - accuracy: 0.8634 - val_loss: 0.2114 - val_accuracy: 0.8888
# Epoch 6/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2101 - accuracy: 0.8916 - val_loss: 0.2002 - val_accuracy: 0.9029
# Epoch 7/20
# ...

# %%
# Evaluate the model on the test data
score = model1.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1714 - accuracy: 0.9089
# Test loss: 0.1714
# Test accuracy: 0.9089

# %%
# Plot the history from the training run
plot_results(history1)

# %% [markdown]
# # Part 11: More questions
#
# Question 8: What happens if you add several Dense layers without specifying the activation function?
#
#     The output of these Dense layers is same as the input of the layers, it make no contributes to the accuary.
#
# Question 9: How are the weights in each dense layer initialized as default? How are the bias weights initialized?
#
#     The weights in each dense layer initialized as a matrix of glorot uniform distribution.The bias weights initialized as n zero vector.

# %% [markdown]
# # Part 12: Balancing the classes
#
# This dataset is rather unbalanced, we need to define class weights so that the training pays more attention to the class with fewer samples. We use a function in scikit learn
#
# https://scikit-learn.org/stable/modules/generated/sklearn.utils.class_weight.compute_class_weight.html

# %%
from sklearn.utils import class_weight

# Calculate class weights


class_weight_calc = class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(Y), y=Y)
weights_of_class={0:class_weight_calc[0],1:class_weight_calc[1]}

# Print the class weights

print(weights_of_class)

# Keras wants the weights in this form, uncomment and change value1 and value2 to your weights, 
# or get them from the array that is returned from class_weight

#class_weights = {0: value1,
#                 1: value2}
# Out:
# {0: 3.1414681675039673, 1: 0.5946443357052587}

# %% [markdown]
# ### 2 layers, 20 nodes, class weights

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model
model2 = build_DNN(input_shape, n_layers=2, n_nodes=20, act_fun='sigmoid', optimizer='sgd', learning_rate=0.1)

# Train the model, provide training data and validation data
history2 = model1.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)
model2.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 11ms/step - loss: 0.2062 - accuracy: 0.8995 - val_loss: 0.2352 - val_accuracy: 0.8987
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1937 - accuracy: 0.8974 - val_loss: 0.2355 - val_accuracy: 0.8994
# Epoch 3/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1922 - accuracy: 0.8984 - val_loss: 0.2334 - val_accuracy: 0.9005
# Epoch 4/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.1909 - accuracy: 0.8992 - val_loss: 0.2328 - val_accuracy: 0.9013
# Epoch 5/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1897 - accuracy: 0.9000 - val_loss: 0.2318 - val_accuracy: 0.9020
# Epoch 6/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1886 - accuracy: 0.9008 - val_loss: 0.2309 - val_accuracy: 0.9027
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model2.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6975 - accuracy: 0.4557
# Test loss: 0.6975
# Test accuracy: 0.4564

# %%
plot_results(history2)

# %% [markdown]
# # Part 13: More questions
#
# Skip questions 11 and 12 if you run on the CPU
#
# Question 10: Why do we have to use a batch size? Why can't we simply use all data at once? This is more relevant for even larger datasets.
#
#     When the data size is too large, it would be a great challenages to the storing, processing and computing for hardware.
#
# Question 11: How busy is the GPU for a batch size of 100? How much GPU memory is used? Hint: run 'nvidia-smi' on the cloud computer a few times during training.
#
#     In my device (RTX 2070), it takes 4.5% of my GPU computing capacity, and 0.4106 mb GPU memory is used.
#
# Question 12: What is the processing time for one training epoch when the batch size is 100? What is the processing time for one epoch when the batch size is 1,000? What is the processing time for one epoch when the batch size is 10,000? Explain the results.
#
#     Average training time for 100 batch size is 26s 5ms.
#     Average training time for 1000 batch size is 3s 5ms.
#     Average training time for 10000 batch size is 7ms.
#
#     When the batch size is 100, the data will be splited into 5349 pices,and when batch size is 1000, the data will be splited into 535 pices, and when batch size is 10000, the data will be splited into54 pices. As we can see, the when the batch size increaces, the size of the datasets increaces so that the data would be divided into less group. For model training, the small groups of datasets makes the model get through the data more quickly.
#
# Question 13: How many times are the weights in the DNN updated in each training epoch if the batch size is 100? How many times are the weights in the DNN updated in each training epoch if the batch size is 1,000? How many times are the weights in the DNN updated in each training epoch if the batch size is 10,000?
#
#     When batch size is 100,weights in the DNN updated 2301 times，
#     When batch size is 1000,weights in the DNN updated 2301 times，
#     When batch size is 10000,weights in the DNN updated 2301 times.
#
# Question 14: What limits how large the batch size can be?
#
#     The size of the input data.
#
# Question 15: Generally speaking, how is the learning rate related to the batch size? If the batch size is decreased, how should the learning rate be changed?
#
#     The learning rate is decreased if the batch size is decreased
#
# Lets use a batch size of 10,000 from now on, and a learning rate of 0.1.

# %% [markdown]
# # Part 14: Increasing the complexity
#
# Lets try some different configurations of number of layers and number of nodes per layer.
#
# Question 16: How many trainable parameters does the network with 4 dense layers with 50 nodes each have, compared to the initial network with 2 layers and 20 nodes per layer? Hint: use model.summary()
#
#     When layers = 2, nodes=20, there are 2301 trainable parameters,
#     When layers = 4, nodes=50, there are 12351 trainable parameters

# %% [markdown]
# ### 4 layers, 20 nodes, class weights

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model
model3 = build_DNN(input_shape, n_layers=4, n_nodes=20, act_fun='sigmoid', optimizer='sgd', learning_rate=0.1)

history3 = model3.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model3.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 13ms/step - loss: 0.7019 - accuracy: 0.7936 - val_loss: 0.6970 - val_accuracy: 0.1582
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.6924 - accuracy: 0.4286 - val_loss: 0.6940 - val_accuracy: 0.1651
# Epoch 3/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.6948 - accuracy: 0.2813 - val_loss: 0.6905 - val_accuracy: 0.8664
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.6925 - accuracy: 0.6681 - val_loss: 0.6893 - val_accuracy: 0.8715
# Epoch 5/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.6909 - accuracy: 0.8677 - val_loss: 0.6904 - val_accuracy: 0.8882
# Epoch 6/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.6892 - accuracy: 0.8715 - val_loss: 0.6893 - val_accuracy: 0.8888
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model3.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2862 - accuracy: 0.8823
# Test loss: 0.2862
# Test accuracy: 0.8823

# %%
plot_results(history3)

# %% [markdown]
# ### 2 layers, 50 nodes, class weights

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model

model4 = build_DNN(input_shape, n_layers=2, n_nodes=50, act_fun='sigmoid', optimizer='sgd', learning_rate=0.1)

history4 = model4.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model4.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6696 - accuracy: 0.8624 - val_loss: 0.5552 - val_accuracy: 0.8847
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.5022 - accuracy: 0.8837 - val_loss: 0.3633 - val_accuracy: 0.8846
# Epoch 3/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3193 - accuracy: 0.8826 - val_loss: 0.2892 - val_accuracy: 0.8840
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2488 - accuracy: 0.8830 - val_loss: 0.2687 - val_accuracy: 0.8859
# Epoch 5/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.2262 - accuracy: 0.8853 - val_loss: 0.2594 - val_accuracy: 0.8902
# Epoch 6/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2169 - accuracy: 0.8887 - val_loss: 0.2552 - val_accuracy: 0.8926
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model4.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.9055
# Test loss: 0.2304
# Test accuracy: 0.9055

# %%
plot_results(history4)

# %% [markdown]
# ### 4 layers, 50 nodes, class weights

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model
model5 = build_DNN(input_shape, n_layers=4, n_nodes=50, act_fun='sigmoid', optimizer='sgd', learning_rate=0.01)

history5 = model5.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model5.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 13ms/step - loss: 0.7232 - accuracy: 0.8401 - val_loss: 0.6648 - val_accuracy: 0.8416
# Epoch 2/20
# 54/54 [==============================] - 1s 10ms/step - loss: 0.6932 - accuracy: 0.8411 - val_loss: 0.6908 - val_accuracy: 0.8390
# Epoch 3/20
# 54/54 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.8262 - val_loss: 0.6935 - val_accuracy: 0.2099
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.6934 - accuracy: 0.3122 - val_loss: 0.6930 - val_accuracy: 0.7488
# Epoch 5/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.6934 - accuracy: 0.4761 - val_loss: 0.6934 - val_accuracy: 0.2245
# Epoch 6/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.6923 - accuracy: 0.5742 - val_loss: 0.6943 - val_accuracy: 0.1567
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model5.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6900 - accuracy: 0.8801
# Test loss: 0.6900
# Test accuracy: 0.8801

# %%
plot_results(history5)

# %% [markdown]
# # Part 15: Batch normalization
#
# Now add batch normalization after each dense layer in `build_DNN`. Remember to import BatchNormalization from keras.layers.
#
# See https://keras.io/layers/normalization/ for information about how to call the function.
#
# Question 17: Why is batch normalization important when training deep networks?
#
#     It could help the model to reduce the explosive of the gradients, and it could improve the robustness for differernt parameters

# %% [markdown]
# ### 2 layers, 20 nodes, class weights, batch normalization

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model

model6 = build_DNN(input_shape, n_layers=2, n_nodes=20,use_bn=True, act_fun='sigmoid', optimizer='sgd', learning_rate=0.1)

history6 = model6.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model6.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 15ms/step - loss: 0.5225 - accuracy: 0.8613 - val_loss: 0.4001 - val_accuracy: 0.8807
# Epoch 2/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.2604 - accuracy: 0.8792 - val_loss: 0.2869 - val_accuracy: 0.8865
# Epoch 3/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.2305 - accuracy: 0.8796 - val_loss: 0.2450 - val_accuracy: 0.8867
# Epoch 4/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.2201 - accuracy: 0.8800 - val_loss: 0.2323 - val_accuracy: 0.8860
# Epoch 5/20
# 54/54 [==============================] - 1s 11ms/step - loss: 0.2131 - accuracy: 0.8810 - val_loss: 0.2291 - val_accuracy: 0.8890
# Epoch 6/20
# 54/54 [==============================] - 1s 11ms/step - loss: 0.2066 - accuracy: 0.8836 - val_loss: 0.2276 - val_accuracy: 0.8935
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model6.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2226 - accuracy: 0.9138
# Test loss: 0.2226
# Test accuracy: 0.9138

# %%
plot_results(history6)

# %% [markdown]
# # Part 16: Activation function
#
# Try changing the activation function in each layer from sigmoid to ReLU, write down the test accuracy.
#
# Note: the last layer should still have a sigmoid activation function.
#
# https://keras.io/api/layers/activations/

# %% [markdown]
# ### 2 layers, 20 nodes, class weights, ReLU, no batch normalization

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model

model7 = build_DNN(input_shape, n_layers=2, n_nodes=20, act_fun='relu', optimizer='sgd', learning_rate=0.1)

history7 = model7.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model7.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.3926 - accuracy: 0.8798 - val_loss: 0.2602 - val_accuracy: 0.8936
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2047 - accuracy: 0.8951 - val_loss: 0.2387 - val_accuracy: 0.9030
# Epoch 3/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1907 - accuracy: 0.9018 - val_loss: 0.2289 - val_accuracy: 0.9075
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1823 - accuracy: 0.9071 - val_loss: 0.2250 - val_accuracy: 0.9108
# Epoch 5/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1780 - accuracy: 0.9094 - val_loss: 0.2203 - val_accuracy: 0.9122
# Epoch 6/20
# 54/54 [==============================] - 1s 10ms/step - loss: 0.1738 - accuracy: 0.9111 - val_loss: 0.2183 - val_accuracy: 0.9139
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model7.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1986 - accuracy: 0.9173
# Test loss: 0.1986
# Test accuracy: 0.9173

# %%
plot_results(history7)

# %% [markdown]
# # Part 17: Optimizer
#
# Try changing the optimizer from SGD to Adam (with learning rate 0.1 as before). Remember to import the Adam optimizer from keras.optimizers.
#
# https://keras.io/optimizers/

# %% [markdown]
# ### 2 layers, 20 nodes, class weights, Adam optimizer, no batch normalization, sigmoid activations

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model

model8 = build_DNN(input_shape, n_layers=2, n_nodes=20, act_fun='sigmoid', optimizer='adam', learning_rate=0.1)

history8 = model8.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model8.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 12ms/step - loss: 0.3131 - accuracy: 0.8303 - val_loss: 0.2132 - val_accuracy: 0.9156
# Epoch 2/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1694 - accuracy: 0.9152 - val_loss: 0.2065 - val_accuracy: 0.9184
# Epoch 3/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1655 - accuracy: 0.9160 - val_loss: 0.2127 - val_accuracy: 0.9190
# Epoch 4/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1594 - accuracy: 0.9190 - val_loss: 0.1930 - val_accuracy: 0.9209
# Epoch 5/20
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1591 - accuracy: 0.9192 - val_loss: 0.1873 - val_accuracy: 0.9216
# Epoch 6/20
# 54/54 [==============================] - 1s 10ms/step - loss: 0.1565 - accuracy: 0.9199 - val_loss: 0.1952 - val_accuracy: 0.9219
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model8.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1965 - accuracy: 0.9236
# Test loss: 0.1965
# Test accuracy: 0.9236

# %%
plot_results(history8)

# %% [markdown]
# # Part 18: Dropout regularization
#
# Dropout is a type of regularization that can improve accuracy for validation and test data.
#
# Add a Dropout layer after each Dense layer (but not after the final dense layer) in `build_DNN`, with a dropout probability of 50%. Remember to first import the Dropout layer from keras.layers
#
# See https://keras.io/api/layers/regularization_layers/dropout/ for how the Dropout layer works.
#
# ---
#
# Question 18: How does the validation accuracy change when adding dropout?
#
#     When adding dropout, the validation accuracy would increase.
#
# Question 19: How does the test accuracy change when adding dropout?
#
#     When adding dropout, the test accuracy would increase.

# %% [markdown]
# ### 2 layers, 20 nodes, class weights, dropout, SGD optimizer, no batch normalization, sigmoid activations

# %%
# Setup some training parameters
batch_size = 10000
epochs = 20
input_shape = X.shape[1]

# Build and train model
model9 = build_DNN(input_shape, n_layers=2, n_nodes=20, act_fun='sigmoid', optimizer='sgd',use_dropout=True, learning_rate=0.1)

history9 = model9.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model9.summary()
# Out:
# Epoch 1/20
# 54/54 [==============================] - 1s 9ms/step - loss: 0.7286 - accuracy: 0.4933 - val_loss: 0.5909 - val_accuracy: 0.8809
# Epoch 2/20
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6180 - accuracy: 0.6473 - val_loss: 0.4872 - val_accuracy: 0.8812
# Epoch 3/20
# 54/54 [==============================] - 0s 7ms/step - loss: 0.5385 - accuracy: 0.7355 - val_loss: 0.4030 - val_accuracy: 0.8811
# Epoch 4/20
# 54/54 [==============================] - 0s 7ms/step - loss: 0.4688 - accuracy: 0.7881 - val_loss: 0.3436 - val_accuracy: 0.8811
# Epoch 5/20
# 54/54 [==============================] - 0s 8ms/step - loss: 0.4174 - accuracy: 0.8187 - val_loss: 0.3097 - val_accuracy: 0.8812
# Epoch 6/20
# 54/54 [==============================] - 0s 7ms/step - loss: 0.3834 - accuracy: 0.8373 - val_loss: 0.2959 - val_accuracy: 0.8812
# Epoch 7/20
# ...

# %%
# Evaluate model on test data
score = model9.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2648 - accuracy: 0.8890
# Test loss: 0.2648
# Test accuracy: 0.8890

# %%
plot_results(history9)

# %% [markdown]
# # Part 19: Improving performance
#
# Spend some time (30 - 90 minutes) playing with the network architecture (number of layers, number of nodes per layer, activation function) and other hyper parameters (optimizer, learning rate, batch size, number of epochs, degree of regularization). For example, try a much deeper network. How much does the training time increase for a network with 10 layers?
#
# Question 20: How high classification accuracy can you achieve for the test data? What is your best configuration?
#
#     The highest classification accuray we can achieve is 0.9221.
#
#     My best configuration is
#
#         batch_size = 10000,
#         epochs = 200,
#         n_layers=2,
#         n_nodes=40,
#         act_fun='relu',
#         optimizer='adam',
#         use_bn=True,
#         use_dropout=True,
#         learning_rate=0.001.

# %%
# Find your best configuration for the DNN
batch_size = 10000
epochs = 200
input_shape = X.shape[1]
# Build and train DNN

model10 = build_DNN(input_shape, n_layers=2, n_nodes=40, act_fun='relu',use_bn=True, use_dropout=True, optimizer='adam', learning_rate=0.001)

history10 = model10.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)

model10.summary()
# Out:
# Epoch 1/200
# 54/54 [==============================] - 1s 11ms/step - loss: 0.5559 - accuracy: 0.6377 - val_loss: 0.3866 - val_accuracy: 0.8803
# Epoch 2/200
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2895 - accuracy: 0.8825 - val_loss: 0.2432 - val_accuracy: 0.8904
# Epoch 3/200
# 54/54 [==============================] - 0s 8ms/step - loss: 0.2339 - accuracy: 0.8940 - val_loss: 0.2052 - val_accuracy: 0.8994
# Epoch 4/200
# 54/54 [==============================] - 0s 8ms/step - loss: 0.2135 - accuracy: 0.9017 - val_loss: 0.1884 - val_accuracy: 0.9073
# Epoch 5/200
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1993 - accuracy: 0.9067 - val_loss: 0.1843 - val_accuracy: 0.9113
# Epoch 6/200
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1918 - accuracy: 0.9100 - val_loss: 0.1830 - val_accuracy: 0.9137
# Epoch 7/200
# ...

# %%
# Evaluate DNN on test data
score = model10.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1771 - accuracy: 0.9221
# Test loss: 0.1771
# Test accuracy: 0.9221

# %%
plot_results(history10)

# %% [markdown]
# # Part 20: Dropout uncertainty
#
# Dropout can also be used during testing, to obtain an estimate of the model uncertainty. Since dropout will randomly remove connections, the network will produce different results every time the same (test) data is put into the network. This technique is called Monte Carlo dropout. For more information, see this paper http://proceedings.mlr.press/v48/gal16.pdf
#
# To achieve this, we need to redefine the Keras Dropout call by running the cell below, and use 'myDropout' in each call to Dropout, in the cell that defines the DNN. The `build_DNN` function takes two boolean arguments, use_dropout and use_custom_dropout, add a standard Dropout layer if use_dropout is true, add a myDropout layer if use_custom_dropout is true.
#
# Run the same test data through the trained network 100 times, with dropout turned on.
#
# Question 21: What is the mean and the standard deviation of the test accuracy?
#
#     Mean of accuracies 0.8966365694999695 and std of accuracies 0.00015755440756280218

# %%
import keras.backend as K
import keras

class myDropout(keras.layers.Dropout):
    """Applies Dropout to the input.
    Dropout consists in randomly setting
    a fraction `rate` of input units to 0 at each update during training time,
    which helps prevent overfitting.
    # Arguments
        rate: float between 0 and 1. Fraction of the input units to drop.
        noise_shape: 1D integer tensor representing the shape of the
            binary dropout mask that will be multiplied with the input.
            For instance, if your inputs have shape
            `(batch_size, timesteps, features)` and
            you want the dropout mask to be the same for all timesteps,
            you can use `noise_shape=(batch_size, 1, features)`.
        seed: A Python integer to use as random seed.
    # References
        - [Dropout: A Simple Way to Prevent Neural Networks from Overfitting](
           http://www.jmlr.org/papers/volume15/srivastava14a/srivastava14a.pdf)
    """
    def __init__(self, rate, training=True, noise_shape=None, seed=None, **kwargs):
        super(myDropout, self).__init__(rate, noise_shape=None, seed=None,**kwargs)
        self.training = training

        
    def call(self, inputs, training=None):
        if 0. < self.rate < 1.:
            noise_shape = self._get_noise_shape(inputs)

            def dropped_inputs():
                return K.dropout(inputs, self.rate, noise_shape,
                                 seed=self.seed)
            if not training: 
                return K.in_train_phase(dropped_inputs, inputs, training=self.training)
            return K.in_train_phase(dropped_inputs, inputs, training=training)
        return inputs

# %% [markdown]
# ### Your best config, custom dropout

# %%
# Your best training parameters
batch_size = 10000
epochs = 200
input_shape = X.shape[1]

# Build and train model
model11 = build_DNN(input_shape, n_layers=2, n_nodes=40, act_fun='relu', optimizer='adam', learning_rate=0.1,use_custom_dropout=True)

history11 = model11.fit(x=Xtrain,y=Ytrain,epochs=epochs,batch_size=batch_size,validation_data=(Xval,Yval),class_weight=weights_of_class)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 1s 9ms/step - loss: 0.9190 - accuracy: 0.7857 - val_loss: 0.2851 - val_accuracy: 0.8768
# Epoch 2/200
# 54/54 [==============================] - 0s 7ms/step - loss: 0.2217 - accuracy: 0.8763 - val_loss: 0.2695 - val_accuracy: 0.8788
# Epoch 3/200
# 54/54 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.87 - 0s 6ms/step - loss: 0.2218 - accuracy: 0.8772 - val_loss: 0.2703 - val_accuracy: 0.8792
# Epoch 4/200
# 54/54 [==============================] - 0s 7ms/step - loss: 0.2197 - accuracy: 0.8777 - val_loss: 0.2740 - val_accuracy: 0.8782
# Epoch 5/200
# 54/54 [==============================] - 0s 7ms/step - loss: 0.2244 - accuracy: 0.8758 - val_loss: 0.2670 - val_accuracy: 0.8810
# Epoch 6/200
# 54/54 [==============================] - 0s 7ms/step - loss: 0.2176 - accuracy: 0.8802 - val_loss: 0.2644 - val_accuracy: 0.8835
# Epoch 7/200
# ...

# %%
# Run this cell a few times to evalute the model on test data, 
# if you get slightly different test accuracy every time, Dropout during testing is working

# Evaluate model on test data
score = model11.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)
                       
print('Test accuracy: %.4f' % score[1])
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.8964
# Test accuracy: 0.8964

# %%
plot_results(history11)

# %%
# Run the testing 100 times, and save the accuracies in an array

his = list()

for i in range(0,100):
    scores = model11.evaluate(x=Xtest,  y=Ytest, batch_size=batch_size)
    his.append(scores[1])
    pass
     
# Calculate and print mean and std of accuracies

print("Mean of accuracies {} and std of accuracies {}".format(np.mean(his),np.std(his)))
# Out:
# ...
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2461 - accuracy: 0.8967
# Mean of accuracies 0.8966365694999695 and std of accuracies 0.00015755440756280218

# %% [markdown]
# # Part 21: Cross validation uncertainty
#
# Cross validation (CV) is often used to evaluate a model, by training and testing using different subsets of the data it is possible to get the uncertainty as the standard deviation over folds. We here use a help function from scikit-learn to setup the CV, see https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html . Use 10 folds with shuffling, random state 1234.
#
# Note: We here assume that you have found the best hyper parameters, so here the data are only split into training and testing, no validation.
#
# ---
#
# Question 22: What is the mean and the standard deviation of the test accuracy?
#
#     Mean of accuracies 0.5292657613754272 and std of accuracies 0.27952485039365055
#
# Question 23: What is the main advantage of dropout compared to CV for estimating test uncertainty? The difference may not be so large in this notebook, but imagine that you have a network that takes 24 hours to train.
#
#     The main advantage of dropout compared to CV for estimating test uncertainty is that, it takes less time. So when using dropout, the model could get the results more quickly.

# %%
from sklearn.model_selection import StratifiedKFold

# Define 10-fold cross validation
cv_flods = StratifiedKFold(n_splits=10, shuffle=True, random_state=1234)

cv_his=list()

batch_size = 10000
epochs = 200
input_shape = X.shape[1]

# Loop over cross validation folds
for train_index, test_index in cv_flods.split(X, Y):    
    # Calculate class weights for current split
    cv_class_weight = class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(Y[train_index,]), y=Y[train_index,])
    weights_of_class_cv={0:cv_class_weight[0],1:cv_class_weight[1]}
    # Rebuild the DNN model, to not continue training on the previously trained model
    model12 = build_DNN(input_shape, n_layers=2, n_nodes=40, act_fun='relu',use_bn=True, use_dropout=True, optimizer='adam', learning_rate=0.001)
    # Fit the model with training set and class weights for this fold
    history12 = model10.fit(x=X[train_index,],y=Y[train_index,],epochs=epochs,batch_size=batch_size,class_weight=weights_of_class_cv)
    model12.summary()
    # Evaluate the model using the test set for this fold
    score_cv = model12.evaluate(x=X[test_index,],y=Y[test_index,], batch_size=batch_size)
    print('Test loss: %.4f' % score_cv[0])
    print('Test accuracy: %.4f' % score_cv[1])
    # Save the test accuracy in an array
    cv_his.append(score_cv[1])
# Calculate and print mean and std of accuracies
print("Mean of accuracies {} and std of accuracies {}".format(np.mean(cv_his),np.std(cv_his)))
# Out:
# Epoch 1/200
# 69/69 [==============================] - 1s 8ms/step - loss: 0.1483 - accuracy: 0.9205
# Epoch 2/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1491 - accuracy: 0.9206
# Epoch 3/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1475 - accuracy: 0.9208
# Epoch 4/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1481 - accuracy: 0.9207
# Epoch 5/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1487 - accuracy: 0.9204
# Epoch 6/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1478 - accuracy: 0.9206
# Epoch 7/200
# 69/69 [==============================] - 1s 8ms/step - loss: 0.1479 - accuracy: 0.9206
# Epoch 8/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1479 - accuracy: 0.9207
# Epoch 9/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.1480 - accuracy: 0.9207
# Epoch 10/200
# ...

# %% [markdown]
# # Part 22: DNN regression
#
# A similar DNN can be used for regression, instead of classification.
#
# Question 24: How would you change the DNN in order to use it for regression instead?
#
#     Change loss function to the J-squre, and there is no activation function for output layer.

# %% [markdown]
# ## Report
#
# Send in this jupyter notebook, with answers to all questions.
